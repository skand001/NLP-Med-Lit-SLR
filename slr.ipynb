# %%
# import os
# import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#     Paper #                                    Study Reference  Year  \
# 0         1                               Sun, Y. & Platoš, J.  2024
# 1         2                           Tang, Gao, Zhang, & Wang  2023
# 2         3                                        Chen et al.  2020
# 3         4                                      Phatak et al.  2022
# 4         5                                          Xu et al.  2022
# 5         6                                          Lu et al.  2024
# 6         7                                Afsharizadeh et al.  2020
# 7         8                                         Guo et al.  2021
# 8         9                                  Balouch & Hussain  2023
# 9        10                              Sibunruang & Polpinij  2024
# 10       11                       Kedzie, McKeown, & Daume III  2019
# 11       12                    Lin, Guo, Dong, Lyu, Xu, & Chen  2023
# 12       13                           Tan, Kieuvongngam, & Niu  2020
# ...

# %%
df.describe()
# Out:
#         Paper #         Year    ROUGE-1    ROUGE-2    ROUGE-L   Accuracy
# count  20.00000    20.000000  11.000000  10.000000   9.000000   5.000000
# mean   10.50000  2021.800000  42.304879  24.306967  38.811815  77.676000
# std     5.91608     1.641565  27.607603  21.095192  21.045950  31.561768
# min     1.00000  2019.000000   0.390000   0.110000   0.693000  22.000000
# 25%     5.75000  2020.000000  29.327500   6.238750  36.705000  82.560000
# 50%    10.50000  2022.000000  45.210000  20.975000  42.045000  94.205000
# 75%    15.25000  2023.000000  55.106667  41.098750  50.240000  94.205000
# max    20.00000  2024.000000  93.500000  61.200000  69.420000  95.410000

# %%
print(df['Year'].value_counts())
print(df['Dataset'].value_counts())
print(df['Method'].value_counts())
# Out:
# 2023    6
# 2020    6
# 2024    3
# 2022    3
# 2021    1
# 2019    1
# Name: Year, dtype: int64
# Gigaword, CNN/Daily Mail                                    1
# Newsroom, CNN/DM, XSum                                      1
# EBM Corpus, COVID-19 Articles                               1
# Medical Transcripts from MT Samples                         1
# Intracranial aneurysm data                                  1
# MIMIC-III, KCH                                              1
# Wikihow, CNN/Daily Mail, DUC2002 Corpus                     1
# CNN/Daily Mail, Edmunds                                     1
# CORD-19                                                     1
# LCSTS                                                       1
# CNN, DailyMail, New York Times, DUC, Reddit, AMI, PubMed    1
# MEDLINE                                                     1
# MIMIC III                                                   1
# Cochrane Database of Systematic Reviews                     1
# ...

# %%
print(f"Average ROUGE-1: {df['ROUGE-1'].mean():.3f}")
print(f"Average ROUGE-2: {df['ROUGE-2'].mean():.3f}")
print(f"Average ROUGE-L: {df['ROUGE-L'].mean():.3f}")
print(f"Average Accuracy: {df['Accuracy'].mean():.3f}")
# Out:
# Average ROUGE-1: 42.305
# Average ROUGE-2: 24.307
# Average ROUGE-L: 38.812
# Average Accuracy: 77.676

# %%
grouped_by_year = df.groupby('Year').mean()
print(grouped_by_year)
# Out:
#         Paper #    ROUGE-1    ROUGE-2    ROUGE-L  Accuracy
# Year
# 2019  11.000000        NaN        NaN        NaN       NaN
# 2020  13.166667   0.712000   0.533000   0.693000    94.205
# 2021   8.000000  53.020000  22.060000  50.240000       NaN
# 2022   8.000000  33.422222  21.978889  47.601667    82.560
# 2023  11.833333  56.547500  36.433333  41.473333    22.000
# 2024   5.666667  42.582500  22.620000  39.375000    95.410
# /var/folders/n6/lht5v8ls6fb4q8rqxgm08l2m0000gn/T/ipykernel_8721/520649828.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_by_year = df.groupby('Year').mean()

# %%
filtered_df = df[(df['ROUGE-1'] > 50) & (df['ROUGE-2'] > 20)]
print(filtered_df)
# Out:
#    Paper #    Study Reference  Year                                  Dataset  \
# 4        5          Xu et al.  2022                      Medical Examination
# 7        8         Guo et al.  2021  Cochrane Database of Systematic Reviews
# 8        9  Balouch & Hussain  2023                                MIMIC III
#
#                    Method    ROUGE-1    ROUGE-2    ROUGE-L  Accuracy
# 4                  COSSUM  57.193333  45.936667  56.696667     82.56
# 7  BART + CNN/DM + PubMed  53.020000  22.060000  50.240000       NaN
# 8              Biobart-V2  66.340000  61.200000  69.420000       NaN

# %%
# Aggregation: Group by 'Year' and calculate the mean of 'ROUGE-1', 'ROUGE-2', 'ROUGE-L', and 'Accuracy'
grouped_by_year = df.groupby('Year')[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'Accuracy']].mean()

# Print the aggregated results
print("Aggregated Results:")
print(grouped_by_year)

# Visualization: Bar plot of average ROUGE scores by year
fig, ax = plt.subplots(figsize=(10, 6))
grouped_by_year[['ROUGE-1', 'ROUGE-2', 'ROUGE-L']].plot(kind='bar', ax=ax)
ax.set_xlabel('Year')
ax.set_ylabel('Average Score')
ax.set_title('Average ROUGE Scores by Year', fontweight='bold', fontsize=14)
ax.legend(['ROUGE-1', 'ROUGE-2', 'ROUGE-L'])

# Adjust the spacing between subplots
plt.tight_layout()
plt.grid(True)
# Display the plot
plt.show()
# Out:
# Aggregated Results:
#         ROUGE-1    ROUGE-2    ROUGE-L  Accuracy
# Year
# 2019        NaN        NaN        NaN       NaN
# 2020   0.712000   0.533000   0.693000    94.205
# 2021  53.020000  22.060000  50.240000       NaN
# 2022  33.422222  21.978889  47.601667    82.560
# 2023  56.547500  36.433333  41.473333    22.000
# 2024  42.582500  22.620000  39.375000    95.410

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt



# Concatenate all the text from the 'Method' column into a single string
text = ' '.join(df['Method'].astype(str))

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='viridis', max_words=50).generate(text)

# Create a figure and axes
fig, ax = plt.subplots(figsize=(12, 6))

# Display the word cloud
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')

# Set the title
ax.set_title('Word Cloud of Methods', fontweight='bold', fontsize=22)

# Adjust the layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Calculating the total minimum and maximum word count based on the provided sections

# Individual word counts as tuples (min, max)
abstract_word_count = (150, 250)
introduction_word_count = (500, 700)
methodology_word_count = (600, 800)
literature_review_word_count = (1500, 2000)
analysis_synthesis_word_count = (1000, 1500)
conclusion_word_count = (500, 700)

# Calculate total minimum and maximum word count
total_min_words = (abstract_word_count[0] + introduction_word_count[0] +
                   methodology_word_count[0] + literature_review_word_count[0] +
                   analysis_synthesis_word_count[0] + conclusion_word_count[0])

total_max_words = (abstract_word_count[1] + introduction_word_count[1] +
                   methodology_word_count[1] + literature_review_word_count[1] +
                   analysis_synthesis_word_count[1] + conclusion_word_count[1])

total_min_words, total_max_words
# Out:
# (4250, 5950)
